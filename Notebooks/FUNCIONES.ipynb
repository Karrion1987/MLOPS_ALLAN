# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import pyarrow.parquet as pq

# %%
df_games_etl = pd.read_csv('/content/drive/MyDrive/MLOPS - ALLAN/3- ETL_CSV/data_games_etl.csv')
df_reviews_etl = pd.read_csv('/content/drive/MyDrive/MLOPS - ALLAN/3- ETL_CSV/data_reviews_sentiments.csv')
df_items_etl = pd.read_csv('/content/drive/MyDrive/MLOPS - ALLAN/3- ETL_CSV/data_items_etl.csv')

# %%
import pandas as pd
from dateutil import parser

# Función para extraer el año de la fecha
def obtener_anio(fecha):
    try:
        # Intentar convertir la fecha al formato de fecha
        fecha_obj = parser.parse(fecha)
        return fecha_obj.year
    except:
        # Si no se puede convertir, retornar un valor nulo o manejarlo según sea necesario
        return None

# Crear la columna "anio" extrayendo el año de la columna "release_date"
df_games_etl['anio'] = df_games_etl['release_date'].apply(obtener_anio).astype('Int64')

# Mostrar el DataFrame resultante
df_games_etl
# Out:
#               publisher                                             genres  \
# 0             Kotoshiro  ['Action', 'Casual', 'Indie', 'Simulation', 'S...
# 1      Making Fun, Inc.       ['Free to Play', 'Indie', 'RPG', 'Strategy']
# 2          Poolians.com  ['Casual', 'Free to Play', 'Indie', 'Simulatio...
# 3                  彼岸领域                  ['Action', 'Adventure', 'Casual']
# 4                   NaN                                                NaN
# ...                 ...                                                ...
# 30733   Ghost_RUS Games      ['Casual', 'Indie', 'Simulation', 'Strategy']
# 30734            Sacada                    ['Casual', 'Indie', 'Strategy']
# 30735      Laush Studio                  ['Indie', 'Racing', 'Simulation']
# 30736          SIXNAILS                                ['Casual', 'Indie']
# 30737               NaN                                                NaN
#
#                        app_name                     title  \
# ...

# %%
df_games_etl['es_gratis'] = df_games_etl['price'].apply(lambda x: True if x == 0.00 else False)

# %%
df_games_etl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30738 entries, 0 to 30737
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   publisher     22960 non-null  object
#  1   genres        27605 non-null  object
#  2   app_name      30737 non-null  object
#  3   title         28805 non-null  object
#  4   url           30738 non-null  object
#  5   release_date  28801 non-null  object
#  6   tags          30607 non-null  object
#  7   reviews_url   30736 non-null  object
#  8   specs         30085 non-null  object
#  9   price         30738 non-null  float64
#  10  early_access  30738 non-null  float64
#  11  id            30736 non-null  float64
#  12  developer     27584 non-null  object
#  13  anio          28798 non-null  Int64
#  14  es_gratis     30738 non-null  bool
# dtypes: Int64(1), bool(1), float64(3), object(10)
# memory usage: 3.3+ MB

# %%
df_games_etl
# Out:
#               publisher                                             genres  \
# 0             Kotoshiro  ['Action', 'Casual', 'Indie', 'Simulation', 'S...
# 1      Making Fun, Inc.       ['Free to Play', 'Indie', 'RPG', 'Strategy']
# 2          Poolians.com  ['Casual', 'Free to Play', 'Indie', 'Simulatio...
# 3                  彼岸领域                  ['Action', 'Adventure', 'Casual']
# 4                   NaN                                                NaN
# ...                 ...                                                ...
# 30733   Ghost_RUS Games      ['Casual', 'Indie', 'Simulation', 'Strategy']
# 30734            Sacada                    ['Casual', 'Indie', 'Strategy']
# 30735      Laush Studio                  ['Indie', 'Racing', 'Simulation']
# 30736          SIXNAILS                                ['Casual', 'Indie']
# 30737               NaN                                                NaN
#
#                        app_name                     title  \
# ...

# %%
# Exportar CSV

#Especifica el nombre del archivo CSV y la ruta donde deseas guardarlo
nombre_archivo_csv = 'df_games_etl.csv'
ruta_guardado = '/content/drive/MyDrive/MLOPS - ALLAN/4- CSV_API/'

# Combina la ruta y el nombre del archivo
ruta_completa = ruta_guardado + nombre_archivo_csv

# Exporta el DataFrame a un archivo CSV
df_games_etl.to_csv(ruta_completa, index=False)


# Imprime un mensaje de confirmación
print(f"DataFrame exportado exitosamente a: {ruta_completa}")
# Out:
# DataFrame exportado exitosamente a: /content/drive/MyDrive/MLOPS - ALLAN/4- CSV_API/df_games_etl.csv

# %%
# Exportar Parquet

#Especifica el nombre del archivo CSV y la ruta donde deseas guardarlo
nombre_archivo_parquet = 'df_games_etl.parquet'
ruta_guardado = '/content/drive/MyDrive/MLOPS - ALLAN/5- DATA_LIMPIA_PARQUET/'

# Combina la ruta y el nombre del archivo
ruta_completa = ruta_guardado + nombre_archivo_parquet

# Exporta el DataFrame a un archivo parquet
df_games_etl.to_parquet(ruta_completa, engine='pyarrow')

# Imprime un mensaje de confirmación
print(f"DataFrame exportado exitosamente en formato parquet a: {ruta_completa}")
# Out:
# DataFrame exportado exitosamente en formato parquet a: /content/drive/MyDrive/MLOPS - ALLAN/5- DATA_LIMPIA_PARQUET/df_games_etl.parquet

# %%
df_reviews_etl
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1                js41637               http://steamcommunity.com/id/js41637
# 2              evcentric             http://steamcommunity.com/id/evcentric
# 3                  doctr                 http://steamcommunity.com/id/doctr
# 4              maplemage             http://steamcommunity.com/id/maplemage
# ...                  ...                                                ...
# 55827                NaN                                                NaN
# 55828                NaN                                                NaN
# 55829                NaN                                                NaN
# 55830                NaN                                                NaN
# 55831                NaN                                                NaN
#
#                           posted  item_id  \
# ...

# %%
# Exportar CSV

#Especifica el nombre del archivo CSV y la ruta donde deseas guardarlo
nombre_archivo_csv = 'df_reviews_etl.csv'
ruta_guardado = '/content/drive/MyDrive/MLOPS - ALLAN/4- CSV_API/'

# Combina la ruta y el nombre del archivo
ruta_completa = ruta_guardado + nombre_archivo_csv

# Exporta el DataFrame a un archivo CSV
df_reviews_etl.to_csv(ruta_completa, index=False)


# Imprime un mensaje de confirmación
print(f"DataFrame exportado exitosamente a: {ruta_completa}")
# Out:
# DataFrame exportado exitosamente a: /content/drive/MyDrive/MLOPS - ALLAN/4- CSV_API/df_reviews_etl.csv

# %%
desarrolladores= df_games_etl['developer']
print (desarrolladores)
# Out:
# 0                       Kotoshiro
# 1                Secret Level SRL
# 2                    Poolians.com
# 3                            彼岸领域
# 4                             NaN
#                    ...
# 30733          Nikita "Ghost_RUS"
# 30734                      Sacada
# 30735    Laush Dmitriy Sergeevich
# 30736               xropi,stev3ns
# 30737                         NaN
# Name: developer, Length: 30738, dtype: object

# %%
df_items_etl
# Out:
#                    user_id  items_count      steam_id  \
# 0        76561197970982479        277.0  7.656120e+16
# 1                  js41637        888.0  7.656120e+16
# 2                evcentric        137.0  7.656120e+16
# 3               Riot-Punch        328.0  7.656120e+16
# 4                    doctr        541.0  7.656120e+16
# ...                    ...          ...           ...
# 5153204                NaN          NaN           NaN
# 5153205                NaN          NaN           NaN
# 5153206                NaN          NaN           NaN
# 5153207                NaN          NaN           NaN
# 5153208                NaN          NaN           NaN
#
#                                                   user_url  item_id  \
# 0        http://steamcommunity.com/profiles/76561197970...       10
# 1                     http://steamcommunity.com/id/js41637       20
# 2                   http://steamcommunity.com/id/evcentric       30
# ...

# %% [markdown]
# ---
#
# **Funcion developer:
# Cantidad de items y porcentaje de contenido Free por año según empresa desarrolladora**
#
# ---

# %%
import pandas as pd

# Función para calcular la cantidad de items y el porcentaje de contenido gratuito por año
def developer(df, desarrollador):
    # Filtrar el DataFrame por la empresa desarrolladora
    df_desarrollador = df[df['developer'] == desarrollador].copy()

    def obtener_anio(fecha):
        try:
            # Intentar convertir la fecha al formato de fecha
            fecha_obj = parser.parse(fecha)
            return fecha_obj.year
        except:
            # Si no se puede convertir, retornar un valor nulo o manejarlo según sea necesario
            return None

    # Crear la columna "anio" extrayendo el año de la columna "release_date"
    df_games_etl['anio'] = df_games_etl['release_date'].apply(obtener_anio).astype('Int64')

    # Contar la cantidad de items por año
    cantidad_items_por_año = df_desarrollador.groupby('anio').size().reset_index(name='cantidad_items')

    # Contar la cantidad de items gratuitos por año
    cantidad_items_gratuitos_por_año = (df_desarrollador[df_desarrollador['es_gratis']].groupby('anio').size().reset_index(name='cantidad_items_gratuitos')).astype('Int64')

    # Fusionar los DataFrames para obtener la cantidad total y gratuita por año
    resultado = pd.merge(cantidad_items_por_año, cantidad_items_gratuitos_por_año, on='anio', how='left').fillna(0)

    # Calcular el porcentaje de contenido gratuito por año
    resultado['porcentaje_gratuito'] = ((resultado['cantidad_items_gratuitos'] / resultado['cantidad_items']) * 100).round(2)

    # Mostrar el resultado en la consola
    print(resultado)

# %%
# Llamar a la función con un desarrollador específico
developer(df_games_etl, 'xropi,stev3ns' )
# Out:
#    anio  cantidad_items  cantidad_items_gratuitos  porcentaje_gratuito
# 0  2016               1                         0                  0.0
# 1  2017               2                         0                  0.0

# %% [markdown]
# ---
#
# def userdata( User_id : str ): Debe devolver cantidad de dinero gastado por el usuario, el porcentaje de recomendación en base a reviews.recommend y cantidad de items.
#
# ---

# %%
# Se extraen las columnas 'items_count', 'user_id' e 'item_id'
df_gastos_items = df_items_etl[['items_count', 'user_id', 'item_id']]
df_gastos_items
# Out:
#          items_count            user_id  item_id
# 0              277.0  76561197970982479       10
# 1              888.0            js41637       20
# 2              137.0          evcentric       30
# 3              328.0         Riot-Punch       40
# 4              541.0              doctr       50
# ...              ...                ...      ...
# 5153204          NaN                NaN   346330
# 5153205          NaN                NaN   373330
# 5153206          NaN                NaN   388490
# 5153207          NaN                NaN   521570
# 5153208          NaN                NaN   519140
#
# [5153209 rows x 3 columns]

# %%
price_juegos = df_games_etl[['price', 'id']]
# Elimina los duplicados
price_juegos = price_juegos.drop_duplicates(subset='id', keep='first')
# Se renombra 'id' por 'item_id' para unir mas adelante
price_juegos = price_juegos.rename(columns={'id':'item_id'})
price_juegos
# Out:
#        price   item_id
# 0       4.99  761140.0
# 1       0.00  643980.0
# 2       0.00  670290.0
# 3       0.99  767400.0
# 4       2.99  773570.0
# ...      ...       ...
# 30733   1.99  773640.0
# 30734   4.99  733530.0
# 30735   1.99  610660.0
# 30736   4.99  658870.0
# 30737   4.99  681550.0
#
# [30736 rows x 2 columns]

# %%
# Une los dataframes
df_gastos_items = df_gastos_items.merge(price_juegos, on='item_id', how='left')
df_gastos_items
# Out:
#          items_count            user_id  item_id  price
# 0              277.0  76561197970982479       10   9.99
# 1              888.0            js41637       20   4.99
# 2              137.0          evcentric       30   4.99
# 3              328.0         Riot-Punch       40   4.99
# 4              541.0              doctr       50   4.99
# ...              ...                ...      ...    ...
# 5153204          NaN                NaN   346330   0.00
# 5153205          NaN                NaN   373330   0.00
# 5153206          NaN                NaN   388490   0.00
# 5153207          NaN                NaN   521570   0.00
# 5153208          NaN                NaN   519140    NaN
#
# [5153209 rows x 4 columns]

# %%
df_gastos_items[df_gastos_items['price'].isnull()]
# Out:
#          items_count             user_id  item_id  price
# 13             253.0  cadmusthreepointoh    34440    NaN
# 21             524.0       thequeenpanda      340    NaN
# 26              59.0      Rainbow-Dashie     9340    NaN
# 27              99.0          btuty8trgt   228200    NaN
# 37              50.0         Fr0stedLine    17340    NaN
# ...              ...                 ...      ...    ...
# 5153180          NaN                 NaN   493440    NaN
# 5153185          NaN                 NaN   496920    NaN
# 5153193          NaN                 NaN   508380    NaN
# 5153195          NaN                 NaN   510660    NaN
# 5153208          NaN                 NaN   519140    NaN
#
# [951613 rows x 4 columns]

# %%
df_gastos_items_group = df_gastos_items.groupby('user_id')['price'].sum().reset_index()
df_gastos_items_group
# Out:
#                  user_id  price
# 0                --000--   6.99
# 1                --ace--   0.00
# 2              --ionex--   9.99
# 3           -2SV-vuLB-Kg   1.99
# 4      -404PageNotFound-   0.00
# ...                  ...    ...
# 87621             zzonci   9.99
# 87622        zzoptimuszz  19.99
# 87623            zzydrax  59.99
# 87624              zzyfo  19.99
# 87625         zzzmidmiss   9.99
#
# [87626 rows x 2 columns]

# %%
df_count_items = df_gastos_items[['items_count', 'user_id']]
# se eliminan los duplicados
df_count_items = df_count_items.drop_duplicates(subset='user_id', keep='first')
df_count_items
# Out:
#        items_count                  user_id
# 0            277.0        76561197970982479
# 1            888.0                  js41637
# 2            137.0                evcentric
# 3            328.0               Riot-Punch
# 4            541.0                    doctr
# ...            ...                      ...
# 88306        177.0        76561198326700687
# 88307          0.0  XxLaughingJackClown77xX
# 88308          7.0        76561198329548331
# 88309          0.0        edward_tremethick
# 88310          NaN                      NaN
#
# [87627 rows x 2 columns]

# %%
df_gastos_items = df_count_items.merge(df_gastos_items_group, on='user_id', how='right')
df_gastos_items
# Out:
#        items_count            user_id  price
# 0             58.0            --000--   6.99
# 1             44.0            --ace--   0.00
# 2             23.0          --ionex--   9.99
# 3             68.0       -2SV-vuLB-Kg   1.99
# 4            149.0  -404PageNotFound-   0.00
# ...            ...                ...    ...
# 87621          5.0             zzonci   9.99
# 87622         61.0        zzoptimuszz  19.99
# 87623         13.0            zzydrax  59.99
# 87624         84.0              zzyfo  19.99
# 87625         69.0         zzzmidmiss   9.99
#
# [87626 rows x 3 columns]

# %%
# Exportar CSV

#Especifica el nombre del archivo CSV y la ruta donde deseas guardarlo
nombre_archivo_csv = 'df_gastos_items.csv'
ruta_guardado = '/content/drive/MyDrive/MLOPS - ALLAN/4- CSV_API/'

# Combina la ruta y el nombre del archivo
ruta_completa = ruta_guardado + nombre_archivo_csv

# Exporta el DataFrame a un archivo CSV
df_gastos_items.to_csv(ruta_completa, index=False)


# Imprime un mensaje de confirmación
print(f"DataFrame exportado exitosamente a: {ruta_completa}")
# Out:
# DataFrame exportado exitosamente a: /content/drive/MyDrive/MLOPS - ALLAN/4- CSV_API/df_gastos_items.csv

# %%
# Exportar Parquet

#Especifica el nombre del archivo CSV y la ruta donde deseas guardarlo
nombre_archivo_parquet = 'df_gastos_items.parquet'
ruta_guardado = '/content/drive/MyDrive/MLOPS - ALLAN/5- DATA_LIMPIA_PARQUET/'

# Combina la ruta y el nombre del archivo
ruta_completa = ruta_guardado + nombre_archivo_parquet

# Exporta el DataFrame a un archivo parquet
df_gastos_items.to_parquet(ruta_completa, engine='pyarrow')

# Imprime un mensaje de confirmación
print(f"DataFrame exportado exitosamente en formato parquet a: {ruta_completa}")
# Out:
# DataFrame exportado exitosamente en formato parquet a: /content/drive/MyDrive/MLOPS - ALLAN/5- DATA_LIMPIA_PARQUET/df_gastos_items.parquet

# %%
# Exportar Parquet

#Especifica el nombre del archivo CSV y la ruta donde deseas guardarlo
nombre_archivo_parquet = 'df_reviews_etl.parquet'
ruta_guardado = '/content/drive/MyDrive/MLOPS - ALLAN/5- DATA_LIMPIA_PARQUET/'

# Combina la ruta y el nombre del archivo
ruta_completa = ruta_guardado + nombre_archivo_parquet

# Exporta el DataFrame a un archivo parquet
df_reviews_etl.to_parquet(ruta_completa, engine='pyarrow')

# Imprime un mensaje de confirmación
print(f"DataFrame exportado exitosamente en formato parquet a: {ruta_completa}")
# Out:
# DataFrame exportado exitosamente en formato parquet a: /content/drive/MyDrive/MLOPS - ALLAN/5- DATA_LIMPIA_PARQUET/df_reviews_etl.parquet

# %%
def userdata(user_id):
    '''
    Esta función devuelve información sobre un usuario según su 'user_id'.

    Args:
        user_id (str): Identificador único del usuario.

    Returns:
        dict: Un diccionario que contiene información sobre el usuario.
            - 'cantidad_dinero' (int): Cantidad de dinero gastado por el usuario.
            - 'porcentaje_recomendacion' (float): Porcentaje de recomendaciones realizadas por el usuario.
            - 'total_items' (int): Cantidad de items que tiene el usuario.
    '''
    # Filtra por el usuario de interés
    usuario = df_reviews_etl[df_reviews_etl['user_id'] == user_id]
    # Calcula la cantidad de dinero gastado para el usuario de interés
    cantidad_dinero = df_gastos_items[df_gastos_items['user_id']== user_id]['price'].iloc[0]
    # Busca el count_item para el usuario de interés
    count_items = df_gastos_items[df_gastos_items['user_id']== user_id]['items_count'].iloc[0]

    # Calcula el total de recomendaciones realizadas por el usuario de interés
    total_recomendaciones = usuario['recommend'].sum()
    # Calcula el total de reviews realizada por todos los usuarios
    total_reviews = len(df_reviews_etl['user_id'].unique())
    # Calcula el porcentaje de recomendaciones realizadas por el usuario de interés
    porcentaje_recomendaciones = (total_recomendaciones / total_reviews) * 100

    return {
        'cantidad_dinero': int(cantidad_dinero),
        'porcentaje_recomendacion': round(float(porcentaje_recomendaciones), 2),
        'total_items': int(count_items)
        }

# %%
userdata ('zzydrax')
# Out:
# {'cantidad_dinero': 59, 'porcentaje_recomendacion': 0.0, 'total_items': 13}

# %% [markdown]
# ---
#
# def UserForGenre( genero : str ): Debe devolver el usuario que acumula más horas jugadas para el género dado y una lista de la acumulación de horas jugadas por año de lanzamiento.
#
# ---

# %%
df_users_horas = df_items_etl [['user_id', 'item_id', 'playtime_forever']]
df_users_horas
# Out:
#                    user_id  item_id  playtime_forever
# 0        76561197970982479       10                 6
# 1                  js41637       20                 0
# 2                evcentric       30                 7
# 3               Riot-Punch       40                 0
# 4                    doctr       50                 0
# ...                    ...      ...               ...
# 5153204                NaN   346330                 0
# 5153205                NaN   373330                 0
# 5153206                NaN   388490                 3
# 5153207                NaN   521570                 4
# 5153208                NaN   519140                 3
#
# [5153209 rows x 3 columns]

# %%
df_users_horas['user_id'].isnull().value_counts()
# Out:
# True     5064899
# False      88310
# Name: user_id, dtype: int64

# %%
df_games_genres = df_games_etl [['id', 'genres', 'anio']]
df_games_genres
# Out:
#              id                                             genres  anio
# 0      761140.0  ['Action', 'Casual', 'Indie', 'Simulation', 'S...  2018
# 1      643980.0       ['Free to Play', 'Indie', 'RPG', 'Strategy']  2018
# 2      670290.0  ['Casual', 'Free to Play', 'Indie', 'Simulatio...  2017
# 3      767400.0                  ['Action', 'Adventure', 'Casual']  2017
# 4      773570.0                                                NaN  <NA>
# ...         ...                                                ...   ...
# 30733  773640.0      ['Casual', 'Indie', 'Simulation', 'Strategy']  2018
# 30734  733530.0                    ['Casual', 'Indie', 'Strategy']  2018
# 30735  610660.0                  ['Indie', 'Racing', 'Simulation']  2018
# 30736  658870.0                                ['Casual', 'Indie']  2017
# 30737  681550.0                                                NaN  <NA>
#
# [30738 rows x 3 columns]

# %%
df_games_genres = df_games_genres.rename(columns={'id': 'item_id'})
df_games_genres
# Out:
#         item_id                                             genres  anio
# 0      761140.0  ['Action', 'Casual', 'Indie', 'Simulation', 'S...  2018
# 1      643980.0       ['Free to Play', 'Indie', 'RPG', 'Strategy']  2018
# 2      670290.0  ['Casual', 'Free to Play', 'Indie', 'Simulatio...  2017
# 3      767400.0                  ['Action', 'Adventure', 'Casual']  2017
# 4      773570.0                                                NaN  <NA>
# ...         ...                                                ...   ...
# 30733  773640.0      ['Casual', 'Indie', 'Simulation', 'Strategy']  2018
# 30734  733530.0                    ['Casual', 'Indie', 'Strategy']  2018
# 30735  610660.0                  ['Indie', 'Racing', 'Simulation']  2018
# 30736  658870.0                                ['Casual', 'Indie']  2017
# 30737  681550.0                                                NaN  <NA>
#
# [30738 rows x 3 columns]

# %%
import ast
# Convertir los valores de la columna 'genres' a listas
df_games_genres['genres'] = df_games_genres['genres'].apply(lambda x: ast.literal_eval(str(x)) if pd.notna(x) else [])
df_games_genres
# Out:
#         item_id                                             genres  anio
# 0      761140.0      [Action, Casual, Indie, Simulation, Strategy]  2018
# 1      643980.0               [Free to Play, Indie, RPG, Strategy]  2018
# 2      670290.0  [Casual, Free to Play, Indie, Simulation, Sports]  2017
# 3      767400.0                        [Action, Adventure, Casual]  2017
# 4      773570.0                                                 []  <NA>
# ...         ...                                                ...   ...
# 30733  773640.0              [Casual, Indie, Simulation, Strategy]  2018
# 30734  733530.0                          [Casual, Indie, Strategy]  2018
# 30735  610660.0                        [Indie, Racing, Simulation]  2018
# 30736  658870.0                                    [Casual, Indie]  2017
# 30737  681550.0                                                 []  <NA>
#
# [30738 rows x 3 columns]

# %%
# Convierte la columna 'genres' en valores separados para cada fila
df_games_genres = df_games_genres.explode('genres')
df_games_genres
# Out:
#         item_id      genres  anio
# 0      761140.0      Action  2018
# 0      761140.0      Casual  2018
# 0      761140.0       Indie  2018
# 0      761140.0  Simulation  2018
# 0      761140.0    Strategy  2018
# ...         ...         ...   ...
# 30735  610660.0      Racing  2018
# 30735  610660.0  Simulation  2018
# 30736  658870.0      Casual  2017
# 30736  658870.0       Indie  2017
# 30737  681550.0         NaN  <NA>
#
# [71453 rows x 3 columns]

# %%
# Une ambos dataframes
df_genres_horas = df_games_genres.merge(df_users_horas, on='item_id', how='right')
df_genres_horas
# Out:
#            item_id        genres  anio            user_id  playtime_forever
# 0             10.0        Action  2000  76561197970982479                 6
# 1             20.0        Action  1999            js41637                 0
# 2             30.0        Action  2003          evcentric                 7
# 3             40.0        Action  2001         Riot-Punch                 0
# 4             50.0        Action  1999              doctr                 0
# ...            ...           ...   ...                ...               ...
# 10853402  388490.0  Free to Play  2015                NaN                 3
# 10853403  521570.0        Casual  2016                NaN                 4
# 10853404  521570.0  Free to Play  2016                NaN                 4
# 10853405  521570.0         Indie  2016                NaN                 4
# 10853406  519140.0           NaN  <NA>                NaN                 3
#
# [10853407 rows x 5 columns]

# %% [markdown]
# Estos codigos estan comentados porque los archivos no fueron unidos si no que se exportarorn por separados en formato parquet

# %%
'''import ast
# Convertir los valores de la columna 'genres' a listas
df_genres_horas['genres'] = df_genres_horas['genres'].apply(lambda x: ast.literal_eval(str(x)) if pd.notna(x) else [])
df_genres_horas'''

# %%
'''# Convierte la columna 'genres' en valores separados para cada fila
df_genres_separados = df_genres_horas.explode('genres')
df_genres_separados'''

# %%
'''df_genres_separados['user_id'].isnull().value_counts()'''
# Out:
# True     10662843
# False      190564
# Name: user_id, dtype: int64

# %%
# Exportar Parquet

#Especifica el nombre del archivo CSV y la ruta donde deseas guardarlo
nombre_archivo_parquet = 'df_games_genres.parquet'
ruta_guardado = '/content/drive/MyDrive/MLOPS - ALLAN/5- DATA_LIMPIA_PARQUET/'

# Combina la ruta y el nombre del archivo
ruta_completa = ruta_guardado + nombre_archivo_parquet

# Exporta el DataFrame a un archivo parquet
df_games_genres.to_parquet(ruta_completa, engine='pyarrow', compression='gzip')



# Imprime un mensaje de confirmación
print(f"DataFrame exportado exitosamente en formato parquet a: {ruta_completa}")
# Out:
# DataFrame exportado exitosamente en formato parquet a: /content/drive/MyDrive/MLOPS - ALLAN/5- DATA_LIMPIA_PARQUET/df_games_genres.parquet

# %%
# Exportar Parquet

#Especifica el nombre del archivo CSV y la ruta donde deseas guardarlo
nombre_archivo_parquet = 'df_users_horas.parquet'
ruta_guardado = '/content/drive/MyDrive/MLOPS - ALLAN/5- DATA_LIMPIA_PARQUET/'

# Combina la ruta y el nombre del archivo
ruta_completa = ruta_guardado + nombre_archivo_parquet

# Exporta el DataFrame a un archivo parquet
df_users_horas.to_parquet(ruta_completa, engine='pyarrow', compression='gzip')



# Imprime un mensaje de confirmación
print(f"DataFrame exportado exitosamente en formato parquet a: {ruta_completa}")
# Out:
# DataFrame exportado exitosamente en formato parquet a: /content/drive/MyDrive/MLOPS - ALLAN/5- DATA_LIMPIA_PARQUET/df_users_horas.parquet

# %%
import os

# %%
def user_for_genre(genre: str):

    # Une ambos dataframes
    df_genres_horas = df_games_genres.merge(df_users_horas, on='item_id', how='right')

    # Filtra el DataFrame resultante para obtener solo las filas relacionadas con el género dado
    df_filtered = df_genres_horas[df_genres_horas['genres'] == genre]

    if df_filtered.empty:
        return {"message": "No data found for the given genre"}

    # Encontrar el usuario que acumula más horas jugadas para el género dado
    max_user = df_filtered.groupby('user_id')['playtime_forever'].sum().idxmax()

    # Filtrar el DataFrame para obtener solo las filas relacionadas con el usuario que acumula más horas
    df_user_max_hours = df_filtered[df_filtered['user_id'] == max_user]

    # Agrupar por año y sumar las horas jugadas
    horas_por_anio = df_user_max_hours.groupby('anio')['playtime_forever'].sum()

    # Construir el diccionario de resultados
    result_dict = {
        "Usuario con más horas jugadas para Género X": max_user,
        "Horas jugadas": [{"Año": int(year), "Horas": int(hours)} for year, hours in horas_por_anio.reset_index().to_dict(orient='split')['data']]
    }

    return result_dict


    return result_dict

# %%
user_for_genre('Adventure')
# Out:
# {'Usuario con más horas jugadas para Género X': '76561198072493915',
#  'Horas jugadas': [{'Año': 2015, 'Horas': 199170}]}

# %% [markdown]
# ---
#
# def best_developer_year( año : int ): Devuelve el top 3 de desarrolladores con juegos MÁS recomendados por usuarios para el año dado. (reviews.recommend = True y comentarios positivos)
# Ejemplo de retorno: [{"Puesto 1" : X}, {"Puesto 2" : Y},{"Puesto 3" : Z}]
#
# ---

# %%
df_best_developer_anio= df_games_etl [['developer', 'anio', 'id']]
df_best_developer_anio
# Out:
#                       developer  anio        id
# 0                     Kotoshiro  2018  761140.0
# 1              Secret Level SRL  2018  643980.0
# 2                  Poolians.com  2017  670290.0
# 3                          彼岸领域  2017  767400.0
# 4                           NaN  <NA>  773570.0
# ...                         ...   ...       ...
# 30733        Nikita "Ghost_RUS"  2018  773640.0
# 30734                    Sacada  2018  733530.0
# 30735  Laush Dmitriy Sergeevich  2018  610660.0
# 30736             xropi,stev3ns  2017  658870.0
# 30737                       NaN  <NA>  681550.0
#
# [30738 rows x 3 columns]

# %%
df_best_developer_anio = df_best_developer_anio.rename(columns={'id': 'item_id'})
df_best_developer_anio.tail()
# Out:
#                       developer  anio   item_id
# 30733        Nikita "Ghost_RUS"  2018  773640.0
# 30734                    Sacada  2018  733530.0
# 30735  Laush Dmitriy Sergeevich  2018  610660.0
# 30736             xropi,stev3ns  2017  658870.0
# 30737                       NaN  <NA>  681550.0

# %%
df_recomended_= df_reviews_etl [['recommend', 'sentiment_analysis', 'item_id']]
df_recomended_
# Out:
#        recommend  sentiment_analysis  item_id
# 0           True                   2     1250
# 1           True                   2   251610
# 2           True                   2   248820
# 3           True                   2   250320
# 4           True                   1   211420
# ...          ...                 ...      ...
# 55827       True                   2   218230
# 55828       True                   1   294230
# 55829       True                   1   273110
# 55830       True                   1   427730
# 55831       True                   1   387990
#
# [55832 rows x 3 columns]

# %%
df_best_developer_anio = df_best_developer_anio.merge(df_recomended_, on='item_id', how='right')
df_best_developer_anio
# Out:
#                          developer  anio   item_id  recommend  \
# 0             Tripwire Interactive  2009    1250.0       True
# 1                              NaN  <NA>  251610.0       True
# 2                 Hopoo Games, LLC  2013  248820.0       True
# 3                   Telltale Games  2013  250320.0       True
# 4                     FromSoftware  2012  211420.0       True
# ...                            ...   ...       ...        ...
# 55827        Daybreak Game Company  2012  218230.0       True
# 55828  Forever Entertainment S. A.  2014  294230.0       True
# 55829                        Nexon  2014  273110.0       True
# 55830          Evil Tortilla Games  2015  427730.0       True
# 55831                 Axolot Games  2016  387990.0       True
#
#        sentiment_analysis
# 0                       2
# 1                       2
# 2                       2
# 3                       2
# 4                       1
# ...                   ...
# 55827                   2
# ...

# %%
# Exportar CSV

#Especifica el nombre del archivo CSV y la ruta donde deseas guardarlo
nombre_archivo_csv = 'df_best_developer_anio.csv'
ruta_guardado = '/content/drive/MyDrive/MLOPS - ALLAN/4- CSV_API/'

# Combina la ruta y el nombre del archivo
ruta_completa = ruta_guardado + nombre_archivo_csv

# Exporta el DataFrame a un archivo CSV
df_best_developer_anio.to_csv(ruta_completa, index=False)


# Imprime un mensaje de confirmación
print(f"DataFrame exportado exitosamente a: {ruta_completa}")
# Out:
# DataFrame exportado exitosamente a: /content/drive/MyDrive/MLOPS - ALLAN/4- CSV_API/df_best_developer_anio.csv

# %%
# Exportar Parquet

#Especifica el nombre del archivo CSV y la ruta donde deseas guardarlo
nombre_archivo_parquet = 'df_best_developer_anio.parquet'
ruta_guardado = '/content/drive/MyDrive/MLOPS - ALLAN/5- DATA_LIMPIA_PARQUET/'

# Combina la ruta y el nombre del archivo
ruta_completa = ruta_guardado + nombre_archivo_parquet

# Exporta el DataFrame a un archivo parquet
df_best_developer_anio.to_parquet(ruta_completa, engine='pyarrow')

# Imprime un mensaje de confirmación
print(f"DataFrame exportado exitosamente en formato parquet a: {ruta_completa}")
# Out:
# DataFrame exportado exitosamente en formato parquet a: /content/drive/MyDrive/MLOPS - ALLAN/5- DATA_LIMPIA_PARQUET/df_best_developer_anio.parquet

# %%
def best_developer_year(año: int):
    # Filtra el DataFrame para el año dado y donde recommend es True y sentiment_analysis es positivo
    df_filtered = df_best_developer_anio[(df_best_developer_anio['anio'] == año) &
                                    (df_best_developer_anio['recommend'] == True) &
                                    (df_best_developer_anio['sentiment_analysis'] > 1)]

    if df_filtered.empty:
        return None

    # Agrupar por desarrollador y contar la cantidad de juegos recomendados
    top_developers = df_filtered.groupby('developer')['recommend'].sum().sort_values(ascending=False).head(3)

    # Construir el resultado como una lista de diccionarios
    result = [{"Top {}".format(i + 1): developer} for i, (developer, _) in enumerate(top_developers.items())]

    return result

# %%
best_developer_year (2012)
# Out:
# [{'Top 1': 'Valve'},
#  {'Top 2': 'Gearbox Software,Aspyr (Mac &amp; Linux)'},
#  {'Top 3': 'Daybreak Game Company'}]

# %% [markdown]
# ---
#
# def developer_reviews_analysis( desarrolladora : str ): Según el desarrollador, se devuelve un diccionario con el nombre del desarrollador como llave y una lista con la cantidad total de registros de reseñas de usuarios que se encuentren categorizados con un análisis de sentimiento como valor positivo o negativo.
# Ejemplo de retorno: {'Valve' : [Negative = 182, Positive = 278]}
#
# ---

# %%
df_developer_reviews= df_reviews_etl [['sentiment_analysis', 'item_id']]
df_developer_reviews
# Out:
#        sentiment_analysis  item_id
# 0                       2     1250
# 1                       2   251610
# 2                       2   248820
# 3                       2   250320
# 4                       1   211420
# ...                   ...      ...
# 55827                   2   218230
# 55828                   1   294230
# 55829                   1   273110
# 55830                   1   427730
# 55831                   1   387990
#
# [55832 rows x 2 columns]

# %%
df_developer_anio= df_games_etl [['developer', 'id']]
df_developer_anio
# Out:
#                       developer        id
# 0                     Kotoshiro  761140.0
# 1              Secret Level SRL  643980.0
# 2                  Poolians.com  670290.0
# 3                          彼岸领域  767400.0
# 4                           NaN  773570.0
# ...                         ...       ...
# 30733        Nikita "Ghost_RUS"  773640.0
# 30734                    Sacada  733530.0
# 30735  Laush Dmitriy Sergeevich  610660.0
# 30736             xropi,stev3ns  658870.0
# 30737                       NaN  681550.0
#
# [30738 rows x 2 columns]

# %%
df_developer_anio = df_developer_anio.rename(columns={'id': 'item_id'})
df_developer_anio
# Out:
#                       developer   item_id
# 0                     Kotoshiro  761140.0
# 1              Secret Level SRL  643980.0
# 2                  Poolians.com  670290.0
# 3                          彼岸领域  767400.0
# 4                           NaN  773570.0
# ...                         ...       ...
# 30733        Nikita "Ghost_RUS"  773640.0
# 30734                    Sacada  733530.0
# 30735  Laush Dmitriy Sergeevich  610660.0
# 30736             xropi,stev3ns  658870.0
# 30737                       NaN  681550.0
#
# [30738 rows x 2 columns]

# %%
df_developer_anio = df_developer_anio.merge(df_developer_reviews, on='item_id', how='right')
df_developer_anio
# Out:
#                          developer   item_id  sentiment_analysis
# 0             Tripwire Interactive    1250.0                   2
# 1                              NaN  251610.0                   2
# 2                 Hopoo Games, LLC  248820.0                   2
# 3                   Telltale Games  250320.0                   2
# 4                     FromSoftware  211420.0                   1
# ...                            ...       ...                 ...
# 55827        Daybreak Game Company  218230.0                   2
# 55828  Forever Entertainment S. A.  294230.0                   1
# 55829                        Nexon  273110.0                   1
# 55830          Evil Tortilla Games  427730.0                   1
# 55831                 Axolot Games  387990.0                   1
#
# [55832 rows x 3 columns]

# %%
# Exportar CSV

#Especifica el nombre del archivo CSV y la ruta donde deseas guardarlo
nombre_archivo_csv = 'df_developer_anio.csv'
ruta_guardado = '/content/drive/MyDrive/MLOPS - ALLAN/4- CSV_API/'

# Combina la ruta y el nombre del archivo
ruta_completa = ruta_guardado + nombre_archivo_csv

# Exporta el DataFrame a un archivo CSV
df_developer_anio.to_csv(ruta_completa, index=False)


# Imprime un mensaje de confirmación
print(f"DataFrame exportado exitosamente a: {ruta_completa}")
# Out:
# DataFrame exportado exitosamente a: /content/drive/MyDrive/MLOPS - ALLAN/4- CSV_API/df_developer_anio.csv

# %%
# Exportar Parquet

import pyarrow.parquet as pq

#Especifica el nombre del archivo CSV y la ruta donde deseas guardarlo
nombre_archivo_parquet = 'df_developer_anio.parquet'
ruta_guardado = '/content/drive/MyDrive/MLOPS - ALLAN/5- DATA_LIMPIA_PARQUET/'

# Combina la ruta y el nombre del archivo
ruta_completa = ruta_guardado + nombre_archivo_parquet

# Exporta el DataFrame a un archivo parquet
df_developer_anio.to_parquet(ruta_completa, engine='pyarrow')

# Imprime un mensaje de confirmación
print(f"DataFrame exportado exitosamente en formato parquet a: {ruta_completa}")
# Out:
# DataFrame exportado exitosamente en formato parquet a: /content/drive/MyDrive/MLOPS - ALLAN/5- DATA_LIMPIA_PARQUET/df_developer_anio.parquet

# %%
def developer_reviews_analysis(desarrollador: str):
    # Filtra el DataFrame para el desarrollador dado
    df_filtered = df_developer_anio[df_developer_anio['developer'] == desarrollador]

    if df_filtered.empty:
        return None

    # Agrupar por análisis de sentimiento y contar la cantidad de registros
    analysis_counts = df_filtered.groupby('sentiment_analysis').size().to_dict()

    # Construir el resultado como un diccionario con una lista
    result = {desarrollador: [f'Negative = {analysis_counts.get(0, 0)}', f'Positive = {analysis_counts.get(2, 0)}']}

    return result

# %%
developer_reviews_analysis ('Telltale Games')
# Out:
# {'Telltale Games': ['Negative = 125', 'Positive = 314']}
